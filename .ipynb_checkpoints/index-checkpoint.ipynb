# %% [markdown]
# # Оглавление

# %% [markdown]
# ## [Основы Python (Часть 2)](lesson-2.ipynb)
#
# 1. Элементы функционального программирования
#   * Распаковка списков
# 2. Swap в Python. Меняет переменные местами
# 3. Функция zip. "Параллельный" проход по двум спискам
# 4. Функция reversed. Итератор. Проход в обратном порядке
# 5. Функция sorted. Сортировка элементов
# 6. Лямбда-функции (анонимные функции)
# 7. Списковые выражения
#   * Список списков
#   * Транспонирование матрицы
# 8. Тип данных: Словарь (Dictionary)
# 9. Тип данных: Кортеж (Tuple)
# 10. Тип данных: Множество (Set)
# 11. Работа с файлами в Python 3.x
# 12. Модули
# 13. Работа со строками
#   * Функция split()
#   * Функция join()
#   * Функция strip()

# %% [markdown]
# ## [Объекто-ориентированное программирование в Python](lesson-3.ipynb)
#
# 1. Минимальный класс в Python
# 2. Методы класса
# 3. Инициализация и атрибуты объектов
# 4. Создание атрибутов
# 5. Атрибуты классов
# 6. Всё является объектом
# 7. Атрибуты. Функции и методы класса
# 8. Доступ к атрибутам
# 9. "Защищенные" атрибуты
# 10. Переопределение операторов
# 11. Оператор \[\] (квадратные скобки)
# 12. Использование ООП в Python
# 13. Неявная типизация
# 14. Разные способы проектирования
# 15. Особенности для Python
# 16. Документирование кода
# 17. Наследование в Python

# %% [markdown]
# ## [Модули. Обработка ошибок](lesson-4.ipynb)
#
# 1. Модули и пространство имен
# 2. Создание и поиск модулей
# 3. Скрипты как модули
# 4. Обработка аргументов
# 5. Модули. Обработка ошибок
#   * Пользовательские исключения
# 6. Форматирование строк

# %% [markdown]
# ## [Модель данных. Тестирование](lesson-5.ipynb)
#
# 1. Модель данных
# 2. Идентичность объектов
# 3. Изменяемый тип объектов
# 4. Неизменяемый тип объектов
#   * Некоторые операции не допустимы
#   * Некоторые операции создают новый объект
# 5. Контейнеры и изменяемость
# 6. Аргументы функций
# 7. Изменяемые и неизменяемые типы данных
# 8. Конкатенация строк
#   * Вариант 1
#   * Вариант 2
# 9. Копирование
# 10. Словари и множества
# 11. Синглтон
# 12. Сборщик мусора
# 13. Байт-код
# 14. Библиотеки
# 15. Тестирование
#   * Тесты вручную
#   * Тесты с помощью модуля unittest
#   * Тесты с помощью модуля pytest
# 16. Проверка кода. Оператор assert

# %% [markdown]
# ## [Работа с текстом. Декораторы](lesson-6.ipynb)
#
# 1. Работа с кодировками
#   * Первая часть относится к Python версии 2.x
#     * unicode -> str:
#     * str -> unicode:
#   * Строки в Python 3.x
# 2. Регулярные выражения
# 3. Расширенная работа с аргументами
#   * Запаковка аргументов
#   * Смешанные аргументы
#   * Распаковка аргументов
#   * Передача аргументов по ключу
#   * Распаковка по ключу
#   * Запаковка аргументов в словарь
# 4. ООП. Декараторы
#   * Использование декоратора
#   * Классы-декораторы
#   * Метаданные функций
#   * Декоратор staticmethod
#   * Декораторы с аргументами

# %% [markdown]
# ## [Наследование. Работа с вебом](lesson-7.ipynb)
#
# 1. Доступ к переопределенным методам
# 2. Множественное наследование
#   * Ромбовидное наследование
# 3. Работа с интернет-ресурсами
# 4. Обработка XML и HTML
# 5. HTML Parser

# %% [markdown]
# ## [Элементы профессионального программирования](lesson-8.ipynb)
#
# 1. Итераторы. Введение
# 2. Функции-Генераторы
#   * Схема работы генераторов
#   * Генератор random_length_repeat()
#   * Списковое выражение
#   * Генераторное выражение
#   * Упрощенное генераторное выражение
# 3. Итераторы. Теория
# 4. Итерируемые и итераторы
#   * Код для Iterator (Итератор)
#   * Код для Iterable (Итерируемое)
#   * Использование итератора для итерируемого
# 5. Инструменты функционального программирования
#   * Функция map()
#   * Функция enumerate()
#   * Функция filter()
#   * Функция reduce()
# 6. Библиотека itertools (for Python 2)

# %% [markdown]
# ## [Менеджеры контекстов. Переопределение оператора точка. Модификаторы доступа](lesson-9.ipynb)
#
# 1. Контекст с остановкой исключений
# 2. Контекст без исключений
# 3. Менеджер контекста на примере временного файла
# 4. Операторы доступа к атрибутам (оператор точка)
# 5. Оператор getattr(self, name)
# 6. Эмуляция отсутствия атрибута
# 7. Оператор setattr(self, name, value)
# 8. Оператор getattribute(self, name)
# 9. Функции для работы с атрибутами
# 10. Модификаторы доступа
#   * Защищенные атрибуты обозначаются префиксом _ (одинарное подчеркивание)
#   * Закрытые атрибуты обозначаются префиксом __ (двойное подчеркивание)
#   * Декорирование имен
#   * Обзор обозначений
# 11. Оформление атрибутов
#   * Простое оформление атрибутов:
#   * Сложное оформление атрибутов
#   * Перегрузка оператора . (точка)
# 12. Декоратор-дескриптор property()
# 13. Собственный дескриптор
# 14. Еще один пример собственного дескриптора

# %% [markdown]
# ## [Графические интерфейсы](lesson-10.ipynb)
#
# 1. Обзор графических библиотек
#   * Графические интерфейсы: основы
#   * Модель на основе событий
#   * Общая структура программ с GUI
#   * Особенности GUI в Web-приложениях
# 2. Библиотека tkinter
# 3. Библиотека tkinter. Класс Frame
# 4. Библиотека tkinter. Упаковка. Метод pack()
# 5. Библиотека tkinter. Упаковка. Метод grid()
# 6. Библиотека Kivy
#   * Пример программы:
#     * Описание интерфейса - файл my.kv
#     * Основная программа

# %% [markdown]
# ## [Метаклассы](lesson-11.ipynb)
#
# 1. Классы и метаклассы
# 2. Метакласс type
# 3. Универсальный меткласс
# 4. Атрибут \__class\__
# 5. Механизм создания классов
# 6. Изменение метакласса
# 7. Метаклассы в общем виде
# 8. Метаклассы, наследование, разрешение имен
# 9. Пример метакласса
# 10. Абстрактные атрибуты

# %% [markdown]
# ## [Параллельное программирование](lesson-12.ipynb)
#
# 1. Последовательное выполнение
#   * Производительность
#   * Блокирующие задачи
#     * Ожидание действий
#     * Примеры
#   * Параллельное выполнение
#     * Преимущества
#     * Недостатки
# 2. Многопоточные программы
# 3. Наследование от Thread
# 4. Еще пример потоков с этим классом...
# 5. Принудительная остановка потока
# 6. Эксперимент скорости потоков
# 7. Параллельные процессы
# 8. Внешние процессы
# 9. Модуль subprocess
